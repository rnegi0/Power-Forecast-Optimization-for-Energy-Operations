# %% [markdown]
# ## Importing and Loading the dataset

# %%
#import libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as pt

# %%
#load dataset
dataset = pd.read_csv("../data/cleaned_dataset.csv")
dataset
# Out:
#          AT      V       AP     RH      PE
# 0      8.34  40.77  1010.84  90.01  480.48
# 1     23.64  58.49  1011.40  74.20  445.75
# 2     29.74  56.90  1007.15  41.91  438.76
# 3     19.07  49.69  1007.22  76.79  453.09
# 4     11.80  40.66  1017.13  97.20  464.43
# ...     ...    ...      ...    ...     ...
# 9463  15.12  48.92  1011.80  72.93  462.59
# 9464  33.41  77.95  1010.30  59.72  432.90
# 9465  15.99  43.34  1014.20  78.66  465.96
# 9466  17.65  59.87  1018.58  94.65  450.93
# 9467  23.68  51.30  1011.86  71.24  451.67
#
# [9468 rows x 5 columns]

# %% [markdown]
# ##  Environmental Insights

# %%
sb.lineplot(data=dataset, x='AT', y='PE', color = 'lightblue')
pt.title('Temperature (AT) vs Power Output (PE)')
pt.xlabel('Temperature (AT)')
pt.ylabel('Power Output (PE)')

pt.grid(True, linestyle='-', alpha=0.4)
# folder_path1 = "E:\plots" 
# file_name1 = "ATvPE_plot.png"
# pt.savefig(f"{folder_path1}/{file_name1}", dpi=300, bbox_inches='tight') 

pt.show() #As temperature increases, power output tends to decrease — likely due to thermodynamic efficiency loss.

# %% [markdown]
# **Temperature (AT) vs. Power Output (PE)**
#
# **Insight**: Higher temperatures (AT) negatively affect the power output (PE). This is due to reduced efficiency in thermal energy conversion as the ambient temperature increases.

# %%
sb.lineplot(data=dataset, x='V', y='PE')
pt.title('Exhaust Vacuum vs Power Output (PE)')
pt.xlabel('Exhaust Vacuum')
pt.ylabel('Power Output (PE)')

pt.grid(True, linestyle='-', alpha=0.4)

# folder_path2 = "E:\plots" 
# file_name2 = "VvPE.png"
# pt.savefig(f"{folder_path2}/{file_name2}", dpi=300, bbox_inches='tight') 
pt.show()

# %%
pt.figure(figsize=(8, 6))
sb.scatterplot(x=dataset['RH'], y=dataset['PE'], color='blue', alpha=0.7)
pt.title('Relative Humidity (RH) vs Power Output (PE)')
pt.xlabel('Relative Humidity (RH)')
pt.ylabel('Power Output (PE)')

# folder_path4 = "E:\plots" 
# file_name4 = "RHvPE_plot.png"
# pt.savefig(f"{folder_path4}/{file_name4}", dpi=300, bbox_inches='tight') 
pt.show() #High humidity might slightly reduce the efficiency of turbines, but correlation might be weaker.

# %% [markdown]
# **Relative Humidity (RH) vs. Power Output (PE)**
#
# **Insight**: Relative Humidity (RH) has a complex relationship with PE. While higher humidity can cool the environment, leading to slightly improved efficiency, very high levels of RH might reduce the air density, affecting turbine performance.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
sns.heatmap(dataset.corr(), annot=True, cmap="Blues", fmt=".2f")
plt.title("Correlation Between Features")
plt.show()

# %% [markdown]
#  - Ambient Temperature (AT) usually has a strong negative correlation with Power Output.

# %%
sb.lmplot(data=dataset, x="AP", y="PE", height=6, aspect=1.2, line_kws={'color':'lightblue'})
pt.title("Ambient Pressure vs Power Output with Trend Line")
pt.xlabel("Ambient Pressure")
pt.ylabel("Power Output")
pt.show()

# %% [markdown]
# > ## Final Environmental Insights
#  - Reducing operational temperature during peak load times could improve efficiency.
#  - Monitoring vacuum pressure is critical for ensuring optimal power output.

# %% [markdown]
# # Summary of Environmental Insights
#
# | Feature  |                    Environmental Insights                          |
# |----------|--------------------------------------------------------------------|
# |AT	       |High temp reduces efficiency -> lower power output                  |
# |V	       | Affects turbine exhaust performance                                |
# |AP	       | High pressure can slightly improve combustion efficiency           |
# |RH	       | High RH may reduce performance (moisture in air affects combustion)|
